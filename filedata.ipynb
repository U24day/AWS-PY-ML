# %%
import pandas as pd

url = "https://raw.githubusercontent.com/U24day/AWS-PY-ML/main/file.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
url = "https://raw.githubusercontent.com/U24day/AWS-PY-ML/main/data.json"
df = pd.read_json(url)

print(df.head())
# Out:
#        name  age
# 0    nikhil   10
# 1  devendra   20
# 2       raj   30
# 3     hello   40

# %%
url = "https://raw.githubusercontent.com/U24day/AWS-PY-ML/main/file.xlsx"
df = pd.read_excel(url)

print(df.head())
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
import pandas as pd

data = {
    "Emp_ID": [101, 102, 103, 104, 105, 106],
    "Name": ["Amit", "Riya", "Raj", "Sara", "John", "Neha"],
    "Department": ["IT", "HR", "Finance", "IT", "Sales", "HR"],
    "Salary": [50000, 45000, 60000, 55000, 48000, 52000],
    "Experience": [2, 3, 5, 4, 1, 3]
}

df = pd.DataFrame(data)
print(df.head())
# Out:
# {'Emp_ID': [101, 102, 103, 104, 105, 106], 'Name': ['Amit', 'Riya', 'Raj', 'Sara', 'John', 'Neha'], 'Department': ['IT', 'HR', 'Finance', 'IT', 'Sales', 'HR'], 'Salary': [50000, 45000, 60000, 55000, 48000, 52000], 'Experience': [2, 3, 5, 4, 1, 3]}
#    Emp_ID  Name Department  Salary  Experience
# 0     101  Amit         IT   50000           2
# 1     102  Riya         HR   45000           3
# 2     103   Raj    Finance   60000           5
# 3     104  Sara         IT   55000           4
# 4     105  John      Sales   48000           1
